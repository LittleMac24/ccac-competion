# %%
# 1. Import necessary libraries
from feature_engineer import FeatureEngineer
from data_builder import load_and_merge_data
from pathlib import Path

# IMPORTANT: Make sure your .py file is in a folder like 'src'
# and that your notebook can see it.
from data_builder import load_and_merge_data

# 2. Define the path to your data folder
# This works because the notebook is in the project root,
# and the 'data' folder is right next to it.
project_root = Path.cwd().parent
data_path = project_root / 'data'

# 3. Call your function to get the clean, merged DataFrame
training_df = load_and_merge_data(data_path, bracket_file='bracket_training.csv')

# Now, instantiate and use your class
engineer = FeatureEngineer()
engineer.fit(training_df)
training_featured = engineer.transform(training_df)

training_featured.head()
# Out:
# Data from bracket_training.csv loaded and merged successfully.
# FeatureEngineer has been fitted.
# Feature transformations applied successfully.
#    CustomerID  CustomerAreaCode CustomerPostalCode  \
# 0       47028               NaN              36093
# 1        3511             616.0              49464
# 2       58445             703.0              22210
# 3       28833               NaN              78218
# 4       37899               NaN              14212
#
#    CustomerPostalCodeLatitude  CustomerPostalCodeLongitude CustomerDMACode  \
# 0                     32.5622                     -86.0994           698.0
# 1                     42.8256                     -86.0104           563.0
# 2                     38.8808                     -77.1129           511.0
# 3                     29.4969                     -98.4032           641.0
# 4                     42.8946                     -78.8245           514.0
#
# ...

# %%
import feature_engineer

feature_eng = feature_engineer.FeatureEngineer()

feature_eng.fit(training_df)
training_df = feature_eng.transform(training_df)

training_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import feature_engineer
# ----> 3 feature_eng = feature_engineer.FeatureEngineer()
#       5 feature_eng.fit(training_df)
#       6 training_df = feature_eng.transform(training_df)
#
# AttributeError: module 'feature_engineer' has no attribute 'FeatureEngineer'
